# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sns.set(style="whitegrid")
df = pd.read_csv('dice.csv')
df2 = pd.read_csv('dice2.csv')

# %%
df
# Out:
#                       subject     mode     dice  jaccard
# 0    gonzalez_alegre_pilot_09  passive  0.68540  0.56116
# 1    gonzalez_alegre_pilot_09   active  0.71356  0.59290
# 2    gonzalez_alegre_pilot_13  passive  0.75336  0.63663
# 3    gonzalez_alegre_pilot_13   active  0.74322  0.62377
# 4   gonzalez_allegre_pilot_05  passive  0.84180  0.74692
# 5    gonzalez_alegre_pilot_11  passive  0.44509  0.31425
# 6    gonzalez_alegre_pilot_11   active  0.46460  0.33151
# 7    gonzalez_alegre_pilot_08  passive  0.62742  0.48972
# 8    gonzalez_alegre_pilot_15  passive  0.72979  0.59679
# 9    gonzalez_alegre_pilot_15   active  0.73109  0.60097
# 10   gonzalez_alegre_pilot_06  passive  0.69505  0.56841
# 11   gonzalez_alegre_pilot_06   active  0.70043  0.56768
# 12   gonzalez_alegre_pilot_10  passive  0.74802  0.63372
# 13   gonzalez_alegre_pilot_10   active  0.69243  0.56530
# 14   gonzalez_alegre_pilot_07  passive  0.72826  0.59733
# 15   gonzalez_alegre_pilot_07   active  0.78375  0.66767
# 16   gonzalez_alegre_pilot_12  passive  0.58366  0.43978
# 17   gonzalez_alegre_pilot_12   active  0.74882  0.63548

# %%
cat = sns.boxplot(x="mode", y="dice", data=df)

# %%
df2
# Out:
#     Unnamed: 0                   subject     mode     dice  jaccard
# 0            0  gonzalez_alegre_pilot_09  passive  0.68557  0.56160
# 1            1  gonzalez_alegre_pilot_09   active  0.71388  0.59346
# 2            2  gonzalez_alegre_pilot_13  passive  0.75351  0.63696
# 3            3  gonzalez_alegre_pilot_13   active  0.74341  0.62408
# 4            4  gonzalez_alegre_pilot_11  passive  0.44538  0.31445
# 5            5  gonzalez_alegre_pilot_11   active  0.46469  0.33157
# 6            6  gonzalez_alegre_pilot_08  passive  0.62799  0.49068
# 7            7  gonzalez_alegre_pilot_15  passive  0.71268  0.58271
# 8            8  gonzalez_alegre_pilot_15   active  0.73095  0.60081
# 9            9  gonzalez_alegre_pilot_05  passive  0.84320  0.74833
# 10          10  gonzalez_alegre_pilot_06  passive  0.69513  0.56860
# 11          11  gonzalez_alegre_pilot_06   active  0.70050  0.56791
# 12          12  gonzalez_alegre_pilot_10  passive  0.74872  0.63483
# 13          13  gonzalez_alegre_pilot_10   active  0.69239  0.56529
# 14          14  gonzalez_alegre_pilot_07  passive  0.72822  0.59730
# 15          15  gonzalez_alegre_pilot_07   active  0.78370  0.66768
# 16          16  gonzalez_alegre_pilot_12  passive  0.58388  0.43994
# 17          17  gonzalez_alegre_pilot_12   active  0.74885  0.63547

# %%
plt.figure(figsize=(12,12))
sns.set(font_scale=1.4)
cat2 = sns.boxplot(x="mode", y="dice", data=df2, palette="husl")
cat2.axes.set_title("ROI Overlap by Acquisition Type", fontsize=22)
cat2.set_xlabel("")
cat2.set_ylabel("Dice Index")
plt.savefig("svgs/moco_dice.svg")

# %%
roi_df = pd.read_csv('rois.csv')
roi_df_melt = pd.melt(roi_df, id_vars=['labels'])

# %%
roi_df
# Out:
#     labels  gonzalez_alegre_pilot_09  gonzalez_alegre_pilot_13  \
# 0        2                  0.863324                  0.886445
# 1        3                  0.749269                  0.779518
# 2        4                  0.776216                  0.821647
# 3        7                  0.822681                  0.901198
# 4        8                  0.900866                  0.942188
# 33                  0.630899                  0.860913
# 34                  0.787579                  0.903592
#
#     gonzalez_alegre_pilot_06  gonzalez_alegre_pilot_10  \
# 0                   0.803609                  0.815339
# 1                   0.631641                  0.677252
# 2                   0.867313                  0.729461
# 3                   0.844994                  0.787809
# 4                   0.902952                  0.816436
# 5                   0.885909                  0.877829
# 6                   0.429069                  0.822387
# 7                   0.802791                  0.811434
# 8                   0.755639                  0.746482
# 9                   0.831016                  0.717489
# 10                  0.810020                  0.669189
# 11                  0.885395                  0.906125
# 12                  0.747253                  0.705523
# 13                  0.702822                  0.749667
# 14                  0.758686                  0.622604
# 15                  0.426966                  0.591118
# 16                  0.788525                  0.779772
# 17                  0.816823                  0.869628
# 18                  0.641952                  0.769029
# 19                  0.928004                  0.796376
# 20                  0.783145                  0.842703
# 21                  0.883638                  0.866582
# 22                  0.914597                  0.891622
# 23                  0.784480                  0.843206
# 24                  0.822965                  0.885000
# 25                  0.747343                  0.821411
# 26                  0.881635                  0.799040
# 27                  0.821990                  0.804070
# 28                  0.599251                  0.722110
# 29                  0.847051                  0.790901
# 30                  0.705882                  0.774096
# 31                  0.560561                  0.812968
# 32                  0.552764                  0.822581
# 33                  0.540146                  0.742251
# 34                  0.608043                  0.834085
#
#     gonzalez_alegre_pilot_07  gonzalez_alegre_pilot_12  \
# 0                   0.824984                  0.864104
# 1                   0.714350                  0.765488
# 2                   0.902022                  0.946843
# 3                   0.766861                  0.889361
# 4                   0.872127                  0.935868
# 5                   0.924737                  0.911657
# 6                   0.885836                  0.823235
# 7                   0.845241                  0.881756
# 8                   0.813427                  0.867765
# 9                   0.834066                  0.910963
# 10                  0.757980                  0.867771
# 11                  0.915304                  0.936498
# 12                  0.832896                  0.871651
# 13                  0.846307                  0.887518
# 14                  0.795778                  0.847632
# 15                  0.800000                  0.591029
# 16                  0.883178                  0.830258
# 17                  0.828198                  0.853601
# 18                  0.714143                  0.748932
# 19                  0.884561                  0.939672
# 20                  0.808485                  0.902488
# 21                  0.895981                  0.935502
# 22                  0.935990                  0.913813
# 23                  0.855005                  0.828233
# 24                  0.909611                  0.893509
# 25                  0.895086                  0.884714
# 26                  0.866857                  0.863208
# 27                  0.904776                  0.867641
# 28                  0.751269                  0.497258
# 29                  0.879244                  0.844643
# 30                  0.883448                  0.257649
# 31                  0.831169                  0.207433
# 32                  0.859630                  0.287516
# 33                  0.812431                  0.481687
# 34                  0.871531                  0.647436
#
#     gonzalez_alegre_pilot15
# 0                  0.839834
# 1                  0.716951
# 2                  0.743929
# 3                  0.818665
# 4                  0.824612
# 5                  0.905839
# 6                  0.883028
# 7                  0.887630
# 8                  0.870079
# 9                  0.713525
# 10                 0.658120
# 11                 0.911597
# 12                 0.783580
# 13                 0.872119
# 14                 0.642298
# 15                 0.645469
# 16                 0.853129
# 17                 0.789228
# 18                 0.653811
# 19                 0.673923
# 20                 0.774064
# 21                 0.789594
# 22                 0.868146
# 23                 0.811266
# 24                 0.875014
# 25                 0.816810
# 26                 0.748056
# 27                 0.849444
# 28                 0.739650
# 29                 0.810969
# 30                 0.782996
# 31                 0.722094
# 32                 0.777897
# 33                 0.760512
# 34                 0.894139

# %%
roi_df_melt
# Out:
#      labels                  variable     value
# 0         2  gonzalez_alegre_pilot_09  0.863324
# 1         3  gonzalez_alegre_pilot_09  0.749269
# 2         4  gonzalez_alegre_pilot_09  0.776216
# 3         7  gonzalez_alegre_pilot_09  0.822681
# 4         8  gonzalez_alegre_pilot_09  0.900866
# ..      ...                       ...       ...
# 380     251   gonzalez_alegre_pilot15  0.782996
# 381     252   gonzalez_alegre_pilot15  0.722094
# 382     253   gonzalez_alegre_pilot15  0.777897
# 383     254   gonzalez_alegre_pilot15  0.760512
# 384     255   gonzalez_alegre_pilot15  0.894139
#
# [385 rows x 3 columns]

# %%
plt.figure(figsize=(14,8))
cat3 = sns.boxplot(x="labels", y="value", data=roi_df_melt)
cat3.set_ylabel("Dice Index")
cat3.set_xlabel("Freesurfer segmentation labels")
plt.savefig("svgs/ROI_dice.svg")

# %% [markdown]
# [Here](https://surfer.nmr.mgh.harvard.edu/fswiki/FsTutorial/AnatomicalROI/FreeSurferColorLUT) is the lookup table for the ROI labels.

# %%
volumes = pd.read_csv('volumes.csv')
values=["Left-Thalamus-Proper","Left-Caudate","Left-Putamen","Left-Pallidum","Left-Hippocampus","Left-Amygdala","CSF","Left-Accumbens-area","Left-VentralDC","Right-Thalamus-Proper","Right-Caudate","Right-Putamen","Right-Pallidum","Right-Hippocampus","Right-Amygdala","Right-Accumbens-area","Right-VentralDC","CC_Posterior","CC_Mid_Posterior","CC_Central","CC_Mid_Anterior","CC_Anterior"]
volumes_pivot = volumes.pivot(index="Measure:volume", columns='Mode', values=values)

# %%
df_list = []
for val in values:
    df = volumes_pivot[val]
    df_list.append(df)
master_df = pd.concat(df_list, ignore_index=True)

# %%
sns.set(font_scale=1)

sns.relplot(x="active_12", y="active_24", color=".2", marker="+", data=master_df)
plt.title("ROI volume ($ml^3$)")
plt.xlabel("ABCD_T1w_MPR_vNav_active_RMS_12_T1")
plt.ylabel("ABCD_T1w_MPR_vNav_active_RMS_24_T1")
plt.tight_layout()
plt.subplots_adjust(top=0.75)
plt.savefig('svgs/corr_active.svg')

# %%
sns.relplot(x="passive_9", y="passive_21", color=".2", marker="+", data=master_df)
plt.title("ROI volume ($ml^3$)")
plt.xlabel("ABCD_T1w_MPR_vNav_passive_RMS_9_T1")
plt.ylabel("ABCD_T1w_MPR_vNav_passive_RMS_21_T1")
plt.tight_layout()
plt.subplots_adjust(top=0.75)
plt.savefig('svgs/corr_passive.svg')

# %% [markdown]
# # Just basal ganglia

# %%
values=["Left-Caudate","Left-Putamen","Left-Pallidum","Left-Accumbens-area", "Right-Caudate","Right-Putamen","Right-Pallidum","Right-Accumbens-area"]
volumes_pivot2 = volumes.pivot(index="Measure:volume", columns='Mode', values=values)

# %%
df_list2 = []
for val in values:
    df = volumes_pivot2[val]
    df_list2.append(df)
master_df2 = pd.concat(df_list2, ignore_index=True)

# %%
sns.relplot(x="active_12", y="active_24", color=".2", marker="+", data=master_df2)
plt.title("Basal Ganglia ROI volume ($ml^3$)")
plt.xlabel("ABCD_T1w_MPR_vNav_active_RMS_12_T1")
plt.ylabel("ABCD_T1w_MPR_vNav_active_RMS_24_T1")
plt.tight_layout()
plt.subplots_adjust(top=0.75)
plt.savefig('svgs/bg_corr_active.svg')

# %%
sns.relplot(x="passive_9", y="passive_21", color=".2", marker="+", data=master_df2)
plt.title("Basal Ganglia ROI volume ($ml^3$)")
plt.xlabel("ABCD_T1w_MPR_vNav_passive_RMS_9_T1")
plt.ylabel("ABCD_T1w_MPR_vNav_passive_RMS_21_T1")
plt.tight_layout()
plt.subplots_adjust(top=0.75)
plt.savefig('svgs/bg_corr_passive.svg')
