# %%
import scipy.io
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.3)
accumbens_dist = scipy.io.loadmat('../distributions/accumbens.mat')['D']
caudate_dist = scipy.io.loadmat('../distributions/caudate.mat')['D']
pallidum_dist = scipy.io.loadmat('../distributions/pallidum.mat')['D']
putamen_dist = scipy.io.loadmat('../distributions/putamen.mat')['D']

lthalamus_dist = scipy.io.loadmat('../distributions/lthalamus.mat')['D']
rthalamus_dist = scipy.io.loadmat('../distributions/rthalamus.mat')['D']

Vlcaudate_dist = scipy.io.loadmat('../distributions/Vlcaudate_nooutlier.mat')['D']
Vlpallidum_dist = scipy.io.loadmat('../distributions/Vlpallidum.mat')['D']
Vlputamen_dist = scipy.io.loadmat('../distributions/Vlputamen.mat')['D']
Vlthalamus_dist = scipy.io.loadmat('../distributions/Vlthalamus.mat')['D']

Vrcaudate_dist = scipy.io.loadmat('../distributions/Vrcaudate.mat')['D']
Vrpallidum_dist = scipy.io.loadmat('../distributions/Vrpallidum.mat')['D']
Vrputamen_dist = scipy.io.loadmat('../distributions/Vrputamen.mat')['D']
Vrthalamus_dist = scipy.io.loadmat('../distributions/Vrthalamus.mat')['D']

# %%
def get_bin_number(dist, observed, bins):
    N, bins, patches = plt.hist(dist, bins)
    plt.close()
    #loop through bins, find which bin observed value is in, get index
    i=0
    for i in range(0, len(bins)):
        if observed < bins[i]:
            return i-1
        i=i+1

# %%
# Global values
color1 = sns.xkcd_palette(['denim blue'])
color2 = 'xkcd:faded red'
ylim=500
bins=50
figsize=(12, 8)

# %% [markdown]
# # Freesurfer

# %%
# Whole figure
f,axes = plt.subplots(2,2, figsize=(20, 16), sharey=True)
a1 = sns.distplot(accumbens_dist, kde=False, ax=axes[0,0], color='r', hist_kws={'alpha': 0.75});
a2 = sns.distplot(caudate_dist, kde=False, ax=axes[0,1], color='r', hist_kws={'alpha': 0.75});
a3 = sns.distplot(pallidum_dist, kde=False, ax=axes[1,0], color='r', hist_kws={'alpha': 0.75});
a4 = sns.distplot(putamen_dist, kde=False, ax=axes[1,1], color='r', hist_kws={'alpha': 0.75});

# Set common labels
f.text(0.5, 0.04, 'Diff Score', ha='center', va='center')
f.text(0.06, 0.5, 'Raw Count', ha='center', va='center', rotation='vertical')
plt.suptitle('Distribution of Diff Scores')

# Axes-specific labels
a1.set_xlabel("Nucleus Accumbens")
a2.set_xlabel("Caudate")
a3.set_xlabel("Pallidum")
a4.set_xlabel("Putamen")

plt.savefig('3_nice/distributions.svg')
plt.savefig('3_nice/distributions.png')
plt.show()

# %%
# Individual Figures - Accumbens
acc_obvs = 0.0097
acc_i = get_bin_number(accumbens_dist, acc_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(accumbens_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': .95}, kde=False)
ax.patches[acc_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Nucleus Accumbens')
plt.savefig('3_nice/accumbens.svg')
plt.savefig('3_nice/accumbens.png')
plt.show()

# %%
# Individual Figures - Caudate
cau_obvs = 0.0153
cau_i = get_bin_number(caudate_dist, cau_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(caudate_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[cau_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Caudate')
plt.savefig('3_nice/caudate.svg')
plt.savefig('3_nice/caudate.png')
plt.show()

# %%
# Individual Figures - Pallidum
pal_obvs = 0.0106
pal_i = get_bin_number(pallidum_dist, pal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(pallidum_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[pal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Pallidum')
plt.savefig('3_nice/pallidum.svg')
plt.savefig('3_nice/pallidum.png')
plt.show()

# %%
# Individual Figures - Putamen
put_obvs = 0.0195
put_i = get_bin_number(putamen_dist, put_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(putamen_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[put_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Putamen')
plt.savefig('3_nice/putamen.svg')
plt.savefig('3_nice/putamen.png')
plt.show()

# %%
# Indiidual Figures - Left Thalamus, Vanderbilt pipeline
lthal_obs = -0.0045
lthal_i = get_bin_number(lthalamus_dist, lthal_obs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(lthalamus_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[lthal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Left Thalamus')
plt.savefig('3_nice/l_thalamus.svg')
plt.savefig('3_nice/l_thalamus.png')
plt.show()

# %%
# Individual Figures - Left Thalamus, Vanderbilt pipeline
rthal_obvs = -0.0046
rthal_i = get_bin_number(rthalamus_dist, rthal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(rthalamus_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[rthal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Right Thalamus')
plt.savefig('3_nice/r_thalamus.svg')
plt.savefig('3_nice/r_thalamus.png')
plt.show()

# %% [markdown]
# # Vanderbilt Pipeline

# %%
ylim=710

# %%
# Individual Figures - Left Thalamus, Vanderbilt pipeline
Vlthal_obvs = 0.0116
Vlthal_i = get_bin_number(Vlthalamus_dist, Vlthal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vlthalamus_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vlthal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Left Thalamus')
plt.savefig('3_nice/Vl_thalamus.svg')
plt.savefig('3_nice/Vl_thalamus.png')
plt.show()

# %%
# Individual Figures - Left l_thalamus, Vanderbilt pipeline
Vrthal_obvs = 0.0102
Vrthal_i = get_bin_number(Vrthalamus_dist, Vrthal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vrthalamus_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vrthal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Right Thalamus')
plt.savefig('3_nice/Vr_thalamus.svg')
plt.savefig('3_nice/Vr_thalamus.png')
plt.show()

# %%
# Individual Figures - Left caudate, Vanderbilt pipeline
Vlcau_obvs = 0.0155
Vlcau_i = get_bin_number(Vlcaudate_dist, Vlcau_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vlcaudate_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vlcau_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Left Caudate')
plt.savefig('3_nice/Vlcaudate.svg')
plt.savefig('3_nice/Vlcaudate.png')
plt.show()

# %%
# Individual Figures - Right caudate, Vanderbilt pipeline
Vrcau_obvs = 0.0152
Vrcau_i = get_bin_number(Vrcaudate_dist, Vrcau_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vrcaudate_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vrcau_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Right Caudate')
plt.savefig('3_nice/Vrcaudate.svg')
plt.savefig('3_nice/Vrcaudate.png')
plt.show()

# %%
# Individual Figures - Left pallidum, Vanderbilt pipeline
Vlpal_obvs = 0.0195
Vlpal_i = get_bin_number(Vlpallidum_dist, Vlpal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vlpallidum_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vlpal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Left Pallidum')
plt.savefig('3_nice/Vlpallidum.svg')
plt.savefig('3_nice/Vlpallidum.png')
plt.show()

# %%
# Individual Figures - Left pallidum, Vanderbilt pipeline
Vrpal_obvs = 0.0026
Vrpal_i = get_bin_number(Vrpallidum_dist, Vrpal_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vrpallidum_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vrpal_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Right Pallidum')
plt.savefig('3_nice/Vrpallidum.svg')
plt.savefig('3_nice/Vrpallidum.png')
plt.show()

# %%
# Individual Figures - Left putamen, Vanderbilt pipeline
Vlput_obvs = 0.0052
Vlput_i = get_bin_number(Vlputamen_dist, Vlput_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vlputamen_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vlput_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Left Putamen')
plt.savefig('3_nice/Vlputamen.svg')
plt.savefig('3_nice/Vlputamen.png')
plt.show()

# %%
# Individual Figures - Left putamen, Vanderbilt pipeline
Vrput_obvs = -0.0027
Vrput_i = get_bin_number(Vrputamen_dist, Vrput_obvs, bins)
plt.figure(figsize=figsize)
ax = sns.distplot(Vrputamen_dist, bins=bins, color=color1, norm_hist=False, hist_kws={'alpha': 0.95}, kde=False)
ax.patches[Vrput_i].set_facecolor(color2)
ax.set_xlabel("Diff Score")
ax.set_ylabel("Raw Count")
ax.set_ylim(0, ylim)
ax.set_title(r'Distribution of Diff Scores: Right Putamen')
plt.savefig('3_nice/Vrputamen.svg')
plt.savefig('3_nice/Vrputamen.png')
plt.show()
